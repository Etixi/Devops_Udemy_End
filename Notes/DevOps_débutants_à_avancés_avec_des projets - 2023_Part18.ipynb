# %% [markdown]
# ##**SECTION 18 : Ansible**
#
# |PLAN|
# |----|
# 186. Présentation
# 187. Configurer Ansible et Infra
# 188. Module d'inventaire et de ping
# 189. Inventaire Partie 2
# 190. YAML & JSON
# 191. Commandes ad hoc
# 192. Livre de jeu et modules
# 193. Modules - Rechercher, utiliser, dépanner et répéter
# 194. Configuration Ansible
# 195. Variables et débogage
# 196. Variables de groupe et d'hôte
# 197. Variables factuelles
# 198. Prise de décision
# 199. Boucles
# 200. Modules de fichiers, de copies et de modèles
# 201. Handlers
# 202. Rôles
# 203. Ansible pour AWS
# 204. Code profil V

# %% [markdown]
# + ***Bonjour et bienvenue dans les sessions Ansible. Ansible est l'un des outil DevOps les plus populaires aujourd'hui et aussi mon préféré.***
#
# + ***Nous comprendrons ce qu'est Ansible, comment il fonctionne, et nous allons en voir plusieurs exemples d'automatisation avec Ansible.***
#
# + ***Mais commençons par comprendre un peu l'histoire de l'automatisation de mon propre point de vue en général. C'est aussi ainsi que le monde de l'automatisation a évolué et a également été adopté dans le mouvement DevOps.***
#
# + ***Mais avant même que le DevOps soit si populaire, nous avions l'habitude de faire de l'automatisation. Et c'était l'époque où le système d'exploitation, le script bash d'automatisation associé était pour la tâche Linux d'automatisation. Le script par lots était pour Windows.***
#
# + ***Et puis nous avons commencé à avoir d'autres choses comme l'automatisation de la base de données. La virtualisation est arrivée, le cloud de l'informatique commençait.***
#
# + ***Il fallait faire d'autres genres de l'automatisation également, pas seulement des tâches du système d'exploitation comme une tâche de virtualisation ou une tâche cloud ou tout autre  tâche DB ou toute automatisation du bâtiment.***
#
# + ***Ainsi, les administrateurs système du langage de programmation ou
# l'équipe des opérations a commencé à adopter des langages de programmation comme Python, Ruby dans un ordre. Si je dis Perl, alors Python et Ruby.***
#
# + ***Mais parmi ces trois, le Python a obtenu le plus populaire en raison de ses immenses bibliothèques où l'on a obtenu la bibliothèque pour automatiser divers types de choses.***
#
# + ***`PERL` était aussi très populaire, mais Perl était trop compliqué comme trop de syntaxe. Je dirais que dans ces trois, Python a remporté la course dans l'automatisation avec le temps que nous avons également obtenu `PowerShell`, qui était spécifique à Windows.***
#
# + ***Mais à partir de Windows, vous pouvez automatiser d'autres choses comme l'automatisation liée à `VMware`. Et puis après ça, le temps est venu de l'outil de gestion de configuration.***
#
# +`***Puppet` est entrée et le mot de gestion de la configuration est passée par Puppet. `Puppet` n'a pas été initialement envisagée
# comme outil d'automatisation. Il s'agissait plus de gérer la configuration.***
#
# + ***La perspective était, disons vous avez de nombreux serveurs, vous avez un cluster de serveurs, cluster de serveur web. Prenons l'exemple et à partir de ce cluster du serveur Web que vous avez configuré. Ainsi, presque tous les serveurs Web de cluster sera exactement similaire. La configuration sera similaire, là package, leur état de service sera similaire.***
#
# + ***Mais parfois, nous avions l'habitude d'apporter des modifications à ces serveurs et ils étaient désynchronisés. Certains fichiers de configuration, nous avons apporté des modifications ou l'état du service a diminué, le service s'est arrêté. Tout type de changement lié à la configuration était supposé être géré via un serveur centralisé.***
#
# + ***Un serveur Puppet sur le serveur Puppet aura la configuration de tous vos serveurs. Et le serveur Puppet va s'appliquer comme une loi. Et toutes les machines qu'on veut gérer la configuration aura un agent qui ira régulièrement de requête au serveur Puppet sur sa configuration et tout était dans le bon état.***
#
# + ***L'état de la configuration de votre infrastructure était donc censé être géré via le serveur Puppet. Mais lorsque le mouvement DevOps est arrivé, nous avons commencé à adopter Puppet comme outil d'automatisation. Avec Puppet, nous avons eu une seule pile qui était très agréable et outil simple pour exécuter des commandes sur une machine distante.***
#
# + ***Une combinaison de Puppet et Salt stack était très célèbre.Généralement, nous avions l'habitude d'exécuter des agents Puppet via
# Salt stack, une configuration initiale via Salt stack puis la plupart de la configuration via Puppet.***
#
# + ***C'était donc le genre de combinaison de l'utilisation de plusieurs outils d'automatisation. Et après cela est venu Chef, maintenant
# `Puppet`, en particulier outil de gestion de configuration. Et il n'y avait pas de langage de programmation là-bas.***
#
# + ***Puppet est construit sur Ruby, Salt stack sur Python. Mais nous n'avons pas besoin d'écrire le code Python ou le code Ruby en ce sens qu'il possède son propre langage.***
#
# + ***`Puppet` a son propre langage, DSL de langage spécifique à un domaine. Maintenant, Chef est venu avec plus de gérabilité et plus de pouvoir à l'utilisateur.***
#
# + ***Je suppose que c'est ce que j'ai personnellement ressenti. Nous avions le pouvoir d'écrire le code Ruby également via Chef. Et il y a plus de modèles et plus de fonctionnalités.***
#
# + ***L'interface utilisateur graphique a été là, ce qui était très bien. Il est toujours là, vous pouvez générer des rapports et des trucs comme ça. Mais avec toutes ces fonctionnalités, il est venu avec plus de complications.***
#
# +  ***Il y a trop de pièces mobiles dans Chef. Vous avez un serveur, vous avez un client, vous avez un poste de travail. Maintenant, je ne dis pas que Puppet ou Chef est mauvais, tout n'est qu'une question de cas d'utilisation ou de votre inclination vers un outil qui compte aussi parmi tout cela. Alors maintenant, nous avons la programmation, nous sommes scripting, alors nous sommes un langage de programmation, alors nous avons l'outil de gestion de configuration.***
#
# + ***Et puis est venu Ansible, qui était à nouveau un outil de gestion de configuration développé par Michael Dohan. Ansible a été écrit en Python et parmi tous ceci, Ansible est l'outil d'automatisation le plus simple.***
#
# + ***Il a ensuite été acquis par Red Hat. Et maintenant, vous avez beaucoup de choses dans Ansible. Vous avez la tour Ansible et vous avez des versions d'entreprise. Alors Ansible est venu avec une idée de simplicité, ayant un code très simple pour gérer votre immense infrastructure.***
#
# + ***Ansible est initialement venu plus concentré sur les machines Linux. Ensuite, l'automatisation de Windows a été également possible via Ansible. C'est toujours possible grâce à Ansible.***
#
# + ***Et puis l'automatisation du cloud, puis automatisation des outils de mise en réseau, automatisation des bases de données.***
#
# + ***Il y a tellement d'intégration venu avec Ansible maintenant. Donc, étant simple, c'est aussi devenu un outil d'automatisation très puissant.***
#
# + ***Et nous avons aussi TerraForm maintenant cloud formation qui sont principalement cloud automatisation du cloud. Maintenant Ansible vous pouvez faire l'automatisation, automatisation du cloud avec Ansible.***
#
# + ***Mais TerraForm est un outil d'automatisation plus spécifique au cloud. Et bien sûr, TerraForm prend également en charge d'autres types d'automatisation, mais la spécialisation est dans l'automatisation du cloud.***
#
# + ***Donc c'est une petite histoire de ma part perspective de la façon dont l'automatisation a évolué depuis Bash et scripts par lots aujourd'hui à vous ayant Ansible, TerraForm et ils sont sûrs qu'il y a plus d'outils d'automatisation, mais je parle de l'être le plus populaire et le plus célèbre dans leurs domaines spécifiques.***
#
# + ***Et nous allons apprendre Ansible dans cette session. Voyons quelques cas d'utilisation populaires d'Ansible first automation, n'importe quel système d'automatisation, automatisation Linux, automatisation Windows.***
#
# + ***Vous souhaitez mettre en place des services web, une base de données de configuration des services, démarrer les services, redémarrer les services.***
#
# + ***Vous pouvez faire tous ces types d'automatisation en utilisant Ansible. Sur la même ligne Conduite du changement. Vous pouvez gérer vos machines de production, toute modification de votre serveur de production, vous pouvez le faire via Ansible.***
#
# + ***Si vous écrivez un véritable playbook Ansible, il peut aller directement dans votre documentation. Ça ne va pas être un script très compliqué à comprendre. Si vous écrivez des titres à votre tâche dans Ansible playbook, vous pouvez également l'utiliser dans la documentation.***
#
# + ***Le provisionnement que vous souhaitez définir tout à partir de zéro. Comme je l'ai dit, vous pouvez utiliser Ansible pour lancer le cloud, les instances aiment aussi facile à instancier, vous pouvez lancer et alors vous pouvez configurer des services dessus comme n'importe quel front-end, base de données back-end, services Web.***
#
# + ***Approvisionnement complet que vous pouvez effectuer via Ansible ou orchestration d'automatisation à grande échelle, combinant plusieurs
# outils d'automatisation et scripts ensemble et exécuter dans un ordre approprié.***
#
# + ***Vous pouvez intégrer Ansible à divers autres outils comme Jenkins ou tout autre outil d'intégration ou services cloud que vous pouvez intégrer à Ansible. Il y a tellement d'intégration avec différents outils et services fournis par Ansible, afin que vous puissiez faire une orchestration complète.***
#
# + ***Ansible est vraiment un outil très simple par rapport à d'autres outils ou scripts d'automatisation. C'est aussi très propre. Vous n'avez donc aucun agent dans Ansible, comme dans Puppet, Chef, Salt stack, vous avez les serveurs. Et pour gérer toutes les machines de ces serveurs, vous devez installer l'agent sur toutes les machines cibles.***
#
# + ***Ainsi, si vous gérez 100 serveurs via Puppet, Chef ou Salt Stack, vous devez installer des agents dans tous ces 100 machines. Dans Ansible, vous n'avez pas besoin de le faire. Ansible utilise la connexion existante comme pour Linux, il utilise SSH pour Windows, il utilise winRM, ou il a également des modules basés sur l'API. Donc, en fonction de la cible, il utilisera les bonnes méthodes de communication dans son module.***
#
# + ***Vous n'avez donc pas besoin d'avoir un agent, vous n'avez pas besoin de faire de configuration, et il n'y a pas de bases de données et de stockage compliqué dans ansible***
#
# + ***Vous avez YAML ini ou format texte où vous avez vos playbooks, vos scripts, votre configuration dans ces formats, des formats très simples. La sortie est écrite au format JSON. La configuration est très simple. D'Ansible c'est juste une bibliothèque Python, donc vous pouvez également dire que Pip install Ansible.***
#
# + ***Ou vous pouvez installer Ansible via les gestionnaires de packages si vous souhaitez les mettre à niveau à nouveau. La mise à niveau est également très simple. Donc, vous installez Ansible et juste commencer comme ça.***
#
# + ***Alors vous écrivez le code Ansible, les playbooks, ca va créer des scripts Python pour l'exécuter sur une cible et renvoie la sortie. Il ne reste aucun logiciel résiduel sur la cible ou même sur la même machine.***
#
# + ***Vous n'avez pas besoin d'écrire de langue de programmation pour faire n'importe quelle automatisation. Avec Ansible, vous avez YAML. Donc script Ansible ou playbook Ansible nous l'appelons au format YAML, ce qui est très facile à lire, ce qui est très facile à écrire.***
#
# + ***C'est structuré et a vraiment très peu de complication par rapport à n'importe quel langage de programmation. C'est pourquoi ils disent qu'Ansible est facile à lire et à écrire. Ansible a beaucoup de modules pour effectuer une tâche particulière.***
#
# + ***Ainsi, en dehors de ses modules système, il a des modules qui sont basés sur l'API. Comme vous voulez lancer un facile à instance d'Ansible, vous pouvez le faire. Donc dans ce cas, Ansible sera en utilisant des outils basés sur l'API pour se connecter.***
#
# + ***Donc, pour être précis, pour AWS, il utilise boto qui utilise l'API. Vous pouvez donc effectuer des appels d'URL reposants à partir d'Ansible. Vous pouvez également exécuter dans votre shell, les commande existant ou les commandes Windows PowerShell d'Ansible.***
#
# + ***Tous les scripts existants, vous avez des scripts shell, vous pouvez également l'exécuter via Ansible. Maintenant, comment Ansible se connecte-t-il à sa cible. Maintenant ciblez l'être.***
#
# + ***Il peut s'agir d'un serveur Linux, d'un serveur Windows, ça pourrait être un compte cloud, ça pourrait être une base de données, il pourrait s'agir d'un équipement réseau.***
#
# + ***Donc pour Linux, comme je l'ai dit, il va utiliser SSH. Ainsi, chaque serveur Linux aura SSH, et j'ai dit serveur et tout serveur Linux que vous prendrez, système d'exploitation Linux Server, Ubuntu Server, CentOS, RHEL auront SSH en cours d'exécution.***
#
# + ***Vous n'avez donc pas besoin de configurer quoi que ce soit, les détails SSH et Ansible peuvent se connecter à une machine Linux à l'aide de SSH. Pour Windows, il utilise Winrm.***
#
# + ***Encore une fois, il y aura déjà le service WinRM. Il vous suffit d'activer une connexion à distance. Dans Windows PowerShell, vous devez activer la connexion à distance afin que vous puissiez vous connecter à Windows via la connexion Winrm à distance.***
#
# + ***Pour le cloud comme AWS, Azure, Google Cloud, ou tout autre cloud, il utilise des API. En dehors de cela, vous pouvez également gérer les périphériques réseau tels que les commutateurs et routeurs via Ansible ou même des bases de données.***
#
# + ***Pour la base de données, ça va utiliser ses propres bibliothèques Python. Comme pour mysql, il a la bibliothèque Python MySQL. Donc, ce que je veux dire, c'est que vous n'avez pas besoin de configurer un agent sur la destination ou sur le serveur lui-même. Eh bien, au fait, il n'y a pas de serveur dans Ansible. Ansible est appelé machine de contrôle.***
#
# + ***En général, vous ne l'appelez pas serveur Ansible car il n'exécute aucun service. Comme Puppet Server, il exécute un service. C'est pourquoi c'est Puppet Server, Chef Server, parce qu'il exécute un service, ou Salt Master, Salt Server, il exécute le service.***
#
# + ***Mais Ansible n'exécute aucun service. Il utilise simplement les modules Python, les scripts Python pour vous connecter à la machine cible, videz le script Python, ils sont exécutés, renvoient la sortie, d'accord ? Pour Winrm ou SSH, il va envoyer le script Python vers la destination, exécutez et renvoyez la sortie.***
#
# + ***Mais pour la tâche API, ça va exécuter localement sur la machine de contrôle, d'accord ? Il n'y a aucun endroit où il va envoyer le script. Il va exécuter tous les scripts localement. Vous avez donc une exécution à distance dans Ansible, et vous avez également une exécution locale, et cela dépend totalement de la cible.***
#
# + ***Et vous n'avez pas vraiment besoin de mentionner quoi que ce soit que vous utilisez simplement le module et vous avez mentionné la destination. Toutes ces choses sont abstraites de vous. Ansible fera tout le genre de connexion et exécution dans les coulisses.***
#
# + ***Il n'y a donc pas vraiment d'architecture géniale d'ansible, c'est juste pour comprendre le but comment cela fonctionne vraiment. Exécute. Il faut donc créer un fichier d'inventaire.***
#
# + ***Dans le fichier d'inventaire, vous avez les informations sur la machine cible. Comme par exemple l'adresse IP, le mot de passe des noms d'utilisateur sera mentionné dans le dossier d'inventaire.***
#
# + ***Ansible a beaucoup de modules dans les modules construits qui sont censés effectuer une tâche particulière. Par exemple, l'installation d'un package ou le redémarrage d'un service ou en prenant un instantané du volume EBS.***
#
# + ***Alors comme ça il y en a des centaines et plus de 1000 modules dans Ansible vous écrivez playbook et vous avez mentionné le fichier d'inventaire que c'est l'hébergeur et nous voulons exécuter tel ou tel module sur cet hôte.***
#
# + ***Ce sera donc une tâche dans le playbook. Vous avez mentionné la destination. Quoi qu'il en soit de l'inventaire, c'est l'hôte et ce module doit être exécuté.***
#
# + ***Ensuite, Ansible va utiliser la configuration créer des scripts Python, des packages Python. Le paquet Python signifie un groupe de modules Python comme nous avons vu dans le groupe de fonctions Python.***
#
# + ***Ensemble, nous avons créé un module. Comme ce groupe de modules est appelé package Python. Ainsi, lorsque vous exécutez, cela va créer le package Python, livrez-le à la destination. Disons que le serveur Linux s'exécute là et renvoie la sortie. Si la cible ne fonctionne pas système, probablement un compte cloud.***
#
# + ***Disons que vous lancez une instance EC2. Donc ça va créer le package Python et exécution locale. La simplicité est la beauté et vous devez occupez-vous de cela dans Ansible.***
#
# + ***Ansible est un outil très simple à utiliser par rapport à d'autres automatisations et scripts. Mais il a beaucoup de fonctionnalités.***
#
# + ***Utilisez les fonctionnalités si vous en avez besoin. Tout au long de ces sessions Ansible, nous allons utilisé diverses fonctionnalités Ansible, mais nous allons l'utiliser quand le besoin s'en fait sentir.
# Et je ferai en sorte que ce besoin vienne.***
#
# + ***Donc, vous apprenez toutes ces fonctionnalités. Mais gardez à l'esprit qu'Ansible était construit sur le principe de la simplicité.***
#
# + ***Essayez donc de garder votre code aussi simple que possible. Étant si simple, Ansible est également très puissant. Vous pouvez faire une variété de choses avec Ansible.***
#
# + ***Comme je vous l'ai déjà dit, toujours de l'automatisation du nuage.Vous pouvez exécuter des commandes, vous pouvez exécuter les tâches API, vous pouvez exécuter des scripts.***
#
# + ***Donc, étant si puissant, vous pouvez utiliser Ansible de faire n'importe quoi dans votre infrastructure. Et vous pouvez remplacer tous les autres outils d'automatisation et utilisez simplement Ansible.***
#
# + ***Mais encore une fois, cela dépend encore une fois du besoin et du cas d'utilisation. Également comme si vous faites trop d'automatisation du cloud, la gestion de beaucoup de choses sur le compte cloud, je pense que TerraForm sera meilleur qu'Ansible pour l'automatisation du cloud.***
#
# + ***De même, vous faites votre choix en fonction de votre besoin. Mais le moment venu, Ansible peut faire la plupart de l'automatisation dont vous avez besoin.***

# %% [markdown]
# ###**CONTINUER**
#
# ####**Qu'est-ce qu'Ansible**
#
# ####**Histoire de l'automatisation**
#
# + **Perspective**
#    + 1. Script bash/Batch Scripting
#    + 2. Python/PERL/Ruby
#    + 3. Powershell
#    + 4. Puppet
#    + 5. Salt Stack
#    + 6. Chef
#    + 7. Ansible
#    + 8. Terraform
#
# ####**Ansible**
# + **Cas d'utilisation**
#    + **Automatisation** : Toute automatisation de système
#    + **Gestion des modifications** : modifications du serveur de production
#    + **Provisioning** : Configuration des serveurs à partir de zéro Provisionnement cloud.
#    + **Orchestration** : Cadre d'automatisation à grande échelle.
#
# + **Ansible est simple**
#
#    + **Aucun agent :**
#      + Les machines/services cibles sont accessibles par SSH, winrm et API
#    + **Aucune base de données :**
#      + YAML, INI & textes
#    + **Aucune configuration Compex**
#      + C'est juste une bibliothèque Python.
#    + **Aucun logiciel résiduel**
#      + Pousser le paquet Python
#      + Exécuter
#      + Sortie de retour
#
# + **YAML**
#
#    + Aucune programmation
#    + Structuré
#    + Facile à lire et à écrire
#
# + **API**
#    + URL/appels reposants (par exemple Cloud)
#    + Commandes Shell
#    + Scénarios

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# + **Puissance Ansible**
#    + Peut remplacer presque tous ou n'importe quel outil d'automatisation dans le travail DevOps ou Ops.

# %% [markdown]
# ###**187. Configurer Ansible et Infra**

# %%
    ssh -i Downloads/control.pem ubuntu@3.89.206.2
    ls ~/.ssh/known_hosts
    cat ~/.ssh/known_hosts
    cat /dev/null > ~/.ssh/known_hosts

    ssh -i Downloads/control.pem ubuntu@3.89.206.2
    exit

    ssh -i Downloads/control.pem ubuntu@3.89.206.2
    exit

    ssh -i Downloads/control.pem ubuntu@3.89.206.2
    exit

    ssh -i Downloads/control.pem ubuntu@3.89.206.2
    2  clear
    3  sudo apt update
    4  sudo add-apt-repository --yes --update ppa:ansible/ansible
    5  sudo apt install ansible -y
    6  ansible --version
    7  history

# %% [markdown]
# ####**188. Module d'inventaire et de ping**

# %%
    8  mkdir vprofile
    9  cd vprofile/
   10  mkdir exercise1
   11  cd exercise1/
   12  cd ..
   13  ls
   14  cd vprofile/
   15  ls
   16  cd exercise1/
   17  ls

vim inventory
================================================
all:
 hosts:
  web01:
   ansible_host: 172.31.34.120
   ansible_user: ec2-user
   ansible_ssh_private_key_file: clientkey.pem
=================================================
exit

$ cat Downloads/client-key.pem
-----BEGIN RSA PRIVATE KEY-----

ClQHLLZGzJaN8dYumcUWusR89TUzZ+z7EPoCR8/2/MCtMuhxnW6T
-----END RSA PRIVATE KEY-----

ssh -i Downloads/control.pem ubuntu@3.89.206.2

        cd vprofile/exercise1/
   22  ls
   23  clear
   24  ls
   25  cat inventory
   26  vim clientkey.pem
   27  ls -l
   28  ansible web01 -m ping -i inventory
   29  sudo cat /etc/ansible/ansible.cfg

ubuntu@ip-172-31-33-19:~/vprofile/exercise1$ sudo -i
root@ip-172-31-33-19:~# cd /etc/ansible/
root@ip-172-31-33-19:/etc/ansible# ls
ansible.cfg  hosts  roles
root@ip-172-31-33-19:/etc/ansible# mv ansible.cfg ansible.cfg_backup
root@ip-172-31-33-19:/etc/ansible# ansible-config init --disabled -t all > ansible.cfg
root@ip-172-31-33-19:/etc/ansible# ls
ansible.cfg  ansible.cfg_backup  hosts  roles
root@ip-172-31-33-19:/etc/ansible# vim ansible.cfg
ubuntu@ip-172-31-33-19:~/vprofile/exercise1$ pwd
ubuntu@ip-172-31-33-19:~/vprofile/exercise1$ ls
ubuntu@ip-172-31-33-19:~/vprofile/exercise1$ ansible web01 -m ping -i inventory
ubuntu@ip-172-31-33-19:~/vprofile/exercise1$ chmod 400 clientkey.pem
ubuntu@ip-172-31-33-19:~/vprofile/exercise1$ ansible web01 -m ping -i inventory
ubuntu@ip-172-31-33-19:~/vprofile/exercise1$

# %% [markdown]
# ####**189. Inventaire Partie 2**

# %%
ubuntu@ip-172-31-33-19:~$ ls
ubuntu@ip-172-31-33-19:~$ cd vprofile/
ubuntu@ip-172-31-33-19:~/vprofile$ ls
ubuntu@ip-172-31-33-19:~/vprofile$ cp -r exercise1/ exercise2
ubuntu@ip-172-31-33-19:~/vprofile$ cd exercise2/
ubuntu@ip-172-31-33-19:~/vprofile/exercise2$ ls
ubuntu@ip-172-31-33-19:~/vprofile/exercise2$ vim inventory

============================================================
all:
 hosts:
  web01:
   ansible_host: 172.31.34.120
   ansible_user: ec2-user
   ansible_ssh_private_key_file: clientkey.pem
  web02:
   ansible_host: 172.31.35.70
   ansible_user: ec2-user
   ansible_ssh_private_key_file: clientkey.pem
  db01:
   ansible_host: 172.31.32.52
   ansible_user: ec2-user
   ansible_ssh_private_key_file: clientkey.pem
==============================================================


ubuntu@ip-172-31-33-19:~/vprofile/exercise2$ ansible web02 -m ping -i inventory
ubuntu@ip-172-31-33-19:~/vprofile/exercise2$ ansible db01 -m ping -i inventory
ubuntu@ip-172-31-33-19:~/vprofile/exercise2$ vim inventory
==============================================================
all:
 hosts:
  web01:
   ansible_host: 172.31.34.120
   ansible_user: ec2-user
   ansible_ssh_private_key_file: clientkey.pem
  web02:
   ansible_host: 172.31.35.70
   ansible_user: ec2-user
   ansible_ssh_private_key_file: clientkey.pem
  db01:
   ansible_host: 172.31.32.52
   ansible_user: ec2-user
   ansible_ssh_private_key_file: clientkey.pem

  children:
   webservers:
    hosts:
     web01:
     web02:
   dbservers:
    hosts:
     db01:
   dc_oregon:
    children:
     webservers:
     dbservers:
===========================================================

ubuntu@ip-172-31-33-19:~/vprofile/exercise2$ ansible webservers -m ping -i inventory
ubuntu@ip-172-31-33-19:~/vprofile/exercise2$ ansible dbservers -m ping -i inventory
ubuntu@ip-172-31-33-19:~/vprofile/exercise2$ ansible dc_oregon -m ping -i inventory
ubuntu@ip-172-31-33-19:~/vprofile/exercise2$ ansible all -m ping -i inventory
ubuntu@ip-172-31-33-19:~/vprofile/exercise2$ ansible '*' -m ping -i inventory
ubuntu@ip-172-31-33-19:~/vprofile/exercise2$ ansible 'web*' -m ping -i inventory
ubuntu@ip-172-31-33-19:~/vprofile/exercise2$ cd ..
ubuntu@ip-172-31-33-19:~/vprofile/exercise2$ cp -r exercise2 exercise3
ubuntu@ip-172-31-33-19:~/vprofile$ cd exercise3/
ubuntu@ip-172-31-33-19:~/vprofile/exercise3$ ls
ubuntu@ip-172-31-33-19:~/vprofile/exercise3$ vim inventory
==========================================================
all:
 hosts:
  web01:
   ansible_host: 172.31.34.120
  web02:
   ansible_host: 172.31.35.70
  db01:
   ansible_host: 172.31.32.52

 children:
  webservers:
   hosts:
    web01:
    web02:
  dbservers:
   hosts:
    db01:
  dc_oregon:
   children:
    webservers:
    dbservers:
   vars:
    ansible_user: ec2-user
    ansible_ssh_private_key_file: clientkey.pem
=================================================================

ubuntu@ip-172-31-33-19:~/vprofile/exercise3$ ansible all -m ping -i inventory
ubuntu@ip-172-31-33-19:~/vprofile/exercise3$ vim inventory
=================================================================
all:
 hosts:
  web01:
   ansible_host: 172.31.34.120
  web02:
   ansible_host: 172.31.35.70
  db01:
   ansible_host: 172.31.32.52

 children:
  webservers:
   hosts:
    web01:
    web02:
  dbservers:
   hosts:
    db01:
  dc_oregon:
   children:
    webservers:
    dbservers:
   vars:
    ansible_user: ec2
    ansible_ssh_private_key_file: clientkey.pem
=======================================================================
ubuntu@ip-172-31-33-19:~/vprofile/exercise3$ ansible all -m ping -i inventory
ubuntu@ip-172-31-33-19:~/vprofile/exercise3$ vim inventory
ubuntu@ip-172-31-33-19:~/vprofile/exercise3$ ansible all -m ping -i inventory

# %% [markdown]
# ###**190. YAML & JSON**
#
# + https://docs.ansible.com/ansible/latest/inventory_guide/intro_inventory.html

# %%
ubuntu@ip-172-31-33-19:~/vprofile/exercise3$ cd ..
ubuntu@ip-172-31-33-19:~/vprofile$ ls
ubuntu@ip-172-31-33-19:~/vprofile$ cd exercise1/
ubuntu@ip-172-31-33-19:~/vprofile/exercise1$ ls
ubuntu@ip-172-31-33-19:~/vprofile/exercise1$ cat inventory
ubuntu@ip-172-31-33-19:~/vprofile/exercise1$ vim inventory

# %%
Python Dictionary

{"DevOps": ["AWS", "Jenkins", "Python", "Ansible"], "Development": ["Java", "NodeJS", ".net"], "ansible_facts": {"python": "/usr/bin/python"}}

JSON

{
 "DevOps":
  [
       "AWS",
       "Jenkins",
       "Python",
       "Ansible"
  ],
 "Development":
  [
    "Java",
    "NodeJS",
    ".net"
  ],
 "ansible_facts":
  {
   "python": "/usr/bin/python"
  },
 }


YAML
DevOps:
- AWS
- Jenkins
- Python
- Ansible

Development:
- Java
- NodeJS
- .net

ansible_facts:
  python: /usr/bin/python
  version: 2.7

# %% [markdown]
# ###**191. Commandes ad hoc**

# %%
ubuntu@ip-172-31-33-19:~$ ls
vprofile
ubuntu@ip-172-31-33-19:~$ cd vprofile/
ubuntu@ip-172-31-33-19:~/vprofile$ ls
exercise1  exercise2  exercise3
ubuntu@ip-172-31-33-19:~/vprofile$
ubuntu@ip-172-31-33-19:~/vprofile$ cp -r exercise3 exercise4
ubuntu@ip-172-31-33-19:~/vprofile$ cd exercise4
ubuntu@ip-172-31-33-19:~/vprofile/exercise4$ ls
clientkey.pem  inventory
ubuntu@ip-172-31-33-19:~/vprofile/exercise4$ ansible web01 -m ansible.builtin.yum -a "name=httpd state=present" -i inventory
ubuntu@ip-172-31-33-19:~/vprofile/exercise4$ ansible web01 -m ansible.builtin.yum -a "name=httpd state=present" -i inventory --become
ubuntu@ip-172-31-33-19:~/vprofile/exercise4$ ansible webservers -m ansible.builtin.yum -a "name=httpd state=present" -i inventory --become
ubuntu@ip-172-31-33-19:~/vprofile/exercise4$ ansible webservers -m ansible.builtin.yum -a "name=httpd state=present" -i inventory --become
ubuntu@ip-172-31-33-19:~/vprofile/exercise4$ ansible webservers -m ansible.builtin.yum -a "name=httpd state=absent" -i inventory --become
ubuntu@ip-172-31-33-19:~/vprofile/exercise4$ ansible webservers -m ansible.builtin.yum -a "name=httpd state=present" -i inventory --become
ubuntu@ip-172-31-33-19:~/vprofile/exercise4$ ansible webservers -m ansible.builtin.service -a "name=httpd state=started enabled=yes" -i inventory --become
ubuntu@ip-172-31-33-19:~/vprofile/exercise4$ ansible webservers -m ansible.builtin.service -a "name=httpd state=started enabled=yes" -i inventory --become
ubuntu@ip-172-31-33-19:~/vprofile/exercise4$ vim index.html
ubuntu@ip-172-31-33-19:~/vprofile/exercise4$ ls
ubuntu@ip-172-31-33-19:~/vprofile/exercise4$ ansible webservers -m ansible.builtin.copy -a "src=index.html dest=/var/www/html/index.html" -i inventory --become
ubuntu@ip-172-31-33-19:~/vprofile/exercise4$ ansible webservers -m ansible.builtin.copy -a "src=index.html dest=/var/www/html/index.html" -i inventory --become
ubuntu@ip-172-31-33-19:~/vprofile/exercise4$ vim index.html
ubuntu@ip-172-31-33-19:~/vprofile/exercise4$ ansible webservers -m ansible.builtin.copy -a "src=index.html dest=/var/www/html/index.html" -i inventory --become
ubuntu@ip-172-31-33-19:~/vprofile/exercise4$ ansible webservers -m ansible.builtin.copy -a "src=index.html dest=/var/www/html/index.html" -i inventory --become

# %% [markdown]
# ###**192. Livre de jeu et modules**
#
# ####**Les playbooks sont écrits au format YAML**

# %%
- hosts: websrvgrp
tasks:
  - yum:
    name:httpd
    state:present

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ####**Playbook & Modules**

# %%
ubuntu@ip-172-31-33-19:~/vprofile$ ls
ubuntu@ip-172-31-33-19:~/vprofile$ cp -r exercise4 exercise5
ubuntu@ip-172-31-33-19:~/vprofile$ cd exercise5/
ubuntu@ip-172-31-33-19:~/vprofile/exercise5$ ls
ubuntu@ip-172-31-33-19:~/vprofile/exercise5$ rm -rf index.html
ubuntu@ip-172-31-33-19:~/vprofile/exercise5$ ls
ubuntu@ip-172-31-33-19:~/vprofile/exercise5$ vim web-db.yaml

=======================================================================
---
- name: Webserver setup
  hosts: webservers
  become: yes
  tasks:
   - name: Install httpd
     ansible.builtin.yum:
      name: httpd
      state: present

   - name: Start service
     ansible.builtin.service:
       name: httpd
       state: started
       enabled: yes

- name: DBserver setup
  hosts: dbservers
  become: yes
  tasks:
   - name: Install mariadb-server
     ansible.builtin.yum:
      name : mariadb-server
      state: present
=======================================================================

ubuntu@ip-172-31-33-19:~/vprofile/exercise5$ ansible webservers -m yum -a "name=httpd state=absent" -i inventory --become
ubuntu@ip-172-31-33-19:~/vprofile/exercise5$ ansible-playbook -i inventory web-db.yaml

ubuntu@ip-172-31-33-19:~/vprofile/exercise5$ vim web-db.yaml
ubuntu@ip-172-31-33-19:~/vprofile/exercise5$ ansible-playbook -i inventory web-db.yaml

=============================================================================
---
- name: Webserver setup
  hosts: webservers
  become: yes
  tasks:
   - name: Install httpd
     ansible.builtin.yum:
      name: httpd
      state: present

   - name: Start service
     ansible.builtin.service:
       name: httpd
       state: started
       enabled: yes

- name: DBserver setup
  hosts: dbservers
  become: yes
  tasks:
   - name: Install mariadb-server
     ansible.builtin.yum:
      name : mariadb-server
      state: present

   - name: Start mariadb service
     ansible.builtin.service:
      name: mariadb
      state: started
      enabled: yes
==========================================================================

ubuntu@ip-172-31-33-19:~/vprofile/exercise5$ ansible-playbook -i inventory web-db.yaml -v
ubuntu@ip-172-31-33-19:~/vprofile/exercise5$ ansible-playbook -i inventory web-db.yaml -vv
ubuntu@ip-172-31-33-19:~/vprofile/exercise5$ ansible-playbook -i inventory web-db.yaml -vvv
ubuntu@ip-172-31-33-19:~/vprofile/exercise5$ ansible-playbook -i inventory web-db.yaml -vvvv
ubuntu@ip-172-31-33-19:~/vprofile/exercise5$ ansible-playbook -i inventory web-db.yaml --syntax-check
ubuntu@ip-172-31-33-19:~/vprofile/exercise5$ ansible-playbook -i inventory web-db.yaml -C

# %% [markdown]
# ####**Modules - Find, Use, Troubleshoot & Repeat**

# %%
ubuntu@ip-172-31-33-19:~$ ls
ubuntu@ip-172-31-33-19:~$ cd vprofile/
ubuntu@ip-172-31-33-19:~/vprofile$ ls
ubuntu@ip-172-31-33-19:~/vprofile$ cp -r exercise5 exercise6
ubuntu@ip-172-31-33-19:~/vprofile$ cd exercise6/
ubuntu@ip-172-31-33-19:~/vprofile/exercise6$ mv web-db.yaml web.yaml
ubuntu@ip-172-31-33-19:~/vprofile/exercise6$ ls
ubuntu@ip-172-31-33-19:~/vprofile/exercise6$ vim web.yaml
ubuntu@ip-172-31-33-19:~/vprofile/exercise6$ vim files/index.html
ubuntu@ip-172-31-33-19:~/vprofile/exercise6$ ls
ubuntu@ip-172-31-33-19:~/vprofile/exercise6$ mkdir files
ubuntu@ip-172-31-33-19:~/vprofile/exercise6$ vim files/index.html
ubuntu@ip-172-31-33-19:~/vprofile/exercise6$ ls
ubuntu@ip-172-31-33-19:~/vprofile/exercise6$ ansible-playbook -i inventory web.yaml
ubuntu@ip-172-31-33-19:~/vprofile/exercise6$ ssh -i clientkey.pem ec2-user@172.31.34.120
[ec2-user@ip-172-31-34-120 ~]$ sudo -i
[root@ip-172-31-34-120 ~]# cd /var/www/html/
[root@ip-172-31-34-120 html]# cat index.html.21288.2023-08-20\@15\:07\:52~
[root@ip-172-31-34-120 html]# exit
[ec2-user@ip-172-31-34-120 ~]$ exit
ubuntu@ip-172-31-33-19:~/vprofile/exercise6$ sudo vim /etc/hostname
====================================================================
control
====================================================================
ubuntu@ip-172-31-33-19:~/vprofile/exercise6$ hostname control
ubuntu@ip-172-31-33-19:~/vprofile/exercise6$ sudo hostname control


ssh -i Downloads/control.pem ubuntu@3.89.206.2
sudo -i
ubuntu@control:~$ ls
vprofile
ubuntu@control:~$ cd vprofile/
ubuntu@control:~/vprofile$ ls
exercise1  exercise2  exercise3  exercise4  exercise5  exercise6
ubuntu@control:~/vprofile$ cp -r exercise5 exercise7
ubuntu@control:~/vprofile$ cd exercise7/
ubuntu@control:~/vprofile/exercise7$ ls
clientkey.pem  inventory  web-db.yaml
ubuntu@control:~/vprofile/exercise7$ mv web-db.yaml db.yaml
ubuntu@control:~/vprofile/exercise7$ vim db.yaml

====================================================================
---
- name: DBserver setup
  hosts: dbservers
  become: yes
  tasks:
   - name: Install mariadb-server
     ansible.builtin.yum:
      name : mariadb-server
      state: present

   - name: Start mariadb service
     ansible.builtin.service:
      name: mariadb
      state: started
      enabled: yes

   - name: Create a new database with name 'accounts'
     mysql_db:
      name: accounts
      state: present
========================================================================

ubuntu@control:~/vprofile/exercise7$ ansible-playbook -i inventory db.yaml
ubuntu@control:~/vprofile/exercise7$ cat inventory
all:
 hosts:
  web01:
   ansible_host: 172.31.34.120
  web02:
   ansible_host: 172.31.35.70
  db01:
   ansible_host: 172.31.32.52

 children:
  webservers:
   hosts:
    web01:
    web02:
  dbservers:
   hosts:
    db01:
  dc_oregon:
   children:
    webservers:
    dbservers:
   vars:
    ansible_user: ec2-user
    ansible_ssh_private_key_file: clientkey.pem

ubuntu@control:~/vprofile/exercise7$ ssh -i clientkey.pem ec2-user@172.31.32.52
[ec2-user@ip-172-31-32-52 ~]$ sudo -i
[root@ip-172-31-32-52 ~]# yum search python | grep -i mysql
ubuntu@control:~/vprofile/exercise7$ vim db.yaml
ubuntu@control:~/vprofile/exercise7$ ansible-playbook -i inventory db.yaml
ubuntu@control:~/vprofile/exercise7$ ansible-galaxy collection install community.mysql

ubuntu@control:~/vprofile/exercise7$ vim db.yaml
=============================================================================
---
- name: DBserver setup
  hosts: dbservers
  become: yes
  tasks:
   - name: Install mariadb-server
     ansible.builtin.yum:
      name : mariadb-server
      state: present

   - name: Install pymysql
     ansible.builtin.yum:
      name : python3-PyMySQL
      state: present

   - name: Start mariadb service
     ansible.builtin.service:
      name: mariadb
      state: started
      enabled: yes

   - name: Create a new database with name 'accounts'
     community.mysql.mysql_db:
      name: accounts
      state: present
      login_unix_socket: /var/lib/mysql/mysql.sock

   - name: Create database user with name 'vprofile'
     community.mysql.mysql_user:
      name: vprofile
      password: 'admin943'
      priv: '*.*:ALL'
      state: present
      login_unix_socket: /var/lib/mysql/mysql.sock

=============================================================================
ubuntu@control:~/vprofile/exercise7$ ansible-playbook -i inventory db.yaml

# %% [markdown]
# ###**Ansible Configuration**
#
# ####**Paramètres de configuration Ansible**
# + Modifier le comportement par défaut d'Ansible.
#
# ####**Ordre de configuration Ansible**
#
# + 1. `ANSIBLE_CONFIG` (variable d'environnement si définie)
# + 2. `ansible.cfg` (Dans le répertoire courant)
# + 3. `~/.ansible.cfg` (Dans le répertoire personnel)
# + 4. `/etc/ansible/ansible.cfg`

# %%
ubuntu@control:~/vprofile$ ls
ubuntu@control:~/vprofile$ sudo -i
root@control:~# vim /etc/ansible/ansible.cfg
root@control:~# exit
ubuntu@control:~/vprofile$ ls
ubuntu@control:~/vprofile$ cd exercise7/
ubuntu@control:~/vprofile/exercise7$ ls
clientkey.pem  db.yaml  inventory

ubuntu@control:~/vprofile/exercise7$ vim ansible.cfg
=========================================================================
[defaults]
host_key_checking=False
inventory = ./inventory
forks = 5
log_path = /var/log/ansible.log

[privilege_escalation]
become=True
become_method=sudo
become_ask_pass=False
=========================================================================

ubuntu@control:~/vprofile/exercise7$ ansible-playbook db.yaml
ubuntu@control:~/vprofile/exercise7$ sudo touch /var/log/ansible.log
ubuntu@control:~/vprofile/exercise7$ sudo chown ubuntu.ubuntu /var/log/ansible.log
ubuntu@control:~/vprofile/exercise7$ ansible-playbook db.yaml
ubuntu@control:~/vprofile/exercise7$ cat /var/log/ansible.log
ubuntu@control:~/vprofile/exercise7$ ansible-playbook db.yaml -vv
ubuntu@control:~/vprofile/exercise7$ cat /var/log/ansible.log
ubuntu@control:~/vprofile/exercise7$ ls

# %% [markdown]
# ####**VARIABLES**

# %%
PLAYBOOK                              => Inventory Based                => Roles
- hosts:websrvgrp                     => In Inventory file              => Include variables from files in playbook
vars:                                 => group_vars/all
  http_port:80                        => group_vars/groupname
  sqluser:admin                       => host_vars/hostname

# %% [markdown]
# ####**Variables factuelles : module de configuration**
# + `ansible_os_family`
#    + Nom du système d'exploitation comme RedHat, Debian, etc.
# + `ansible_processor_cores`
#    + Nombre de cœurs `CPU`
# + `ansible_kernel`
#    + version du noyau
# + `ansible_devices`
#    + Informations sur l'appareil connecté
# + `ansible_default_ipv4`
#    + IP, adresse MAC, passerelle, etc.
# + `ansible_architecture`
#    + 64 bits ou 32 bits
#
# ####**Sortie de stockage : module d'enregistrement**
#
# ![image.png](data:image/png;base64,...)

# %%
ubuntu@control:~/vprofile$ ls
ubuntu@control:~/vprofile$ cp -r exercise7 exercise8
ubuntu@control:~/vprofile$ cd exercise8
ubuntu@control:~/vprofile/exercise8$ ls
ubuntu@control:~/vprofile/exercise8$ vim db.yaml
ubuntu@control:~/vprofile/exercise8$ ansible-playbook db.yaml
ubuntu@control:~/vprofile/exercise8$ ansible-playbook db.yaml -vv
ubuntu@control:~/vprofile/exercise8$ vim db.yaml

===============================================================
---
- name: DBserver setup
  hosts: dbservers
  become: yes
  vars:
    dbname: electric
    dbuser: current
    dbpass: tesla
  tasks:
   - debug:
      msg: "The dbname is {{dbname}}"

   - debug:
      var: dbname

   - name: Install mariadb-server
     ansible.builtin.yum:
      name : mariadb-server
      state: present

   - name: Install pymysql
     ansible.builtin.yum:
      name : python3-PyMySQL
      state: present

   - name: Start mariadb service
     ansible.builtin.service:
      name: mariadb
      state: started
      enabled: yes

   - name: Create a new database
     community.mysql.mysql_db:
      name: "{{dbname}}"
      state: present
      login_unix_socket: /var/lib/mysql/mysql.sock

   - name: Create database
     community.mysql.mysql_user:
      name: "{{dbuser}}"
      password: "{{dbpass}}"
      priv: '*.*:ALL'
      state: present
      login_unix_socket: /var/lib/mysql/mysql.sock
=============================================================================

ubuntu@control:~/vprofile/exercise8$ ansible-playbook db.yaml -vv
ubuntu@control:~/vprofile/exercise8$ ansible-playbook db.yaml
ubuntu@control:~/vprofile/exercise8$ vim db.yaml
==============================================================================
---
- name: DBserver setup
  hosts: dbservers
  become: yes
  vars:
    dbname: electric
    dbuser: current
    dbpass: tesla
  tasks:
   - debug:
      msg: "The dbname is {{dbname}}"

   - debug:
      var: dbname

   - name: Install mariadb-server
     ansible.builtin.yum:
      name : mariadb-server
      state: present

   - name: Install pymysql
     ansible.builtin.yum:
      name : python3-PyMySQL
      state: present

   - name: Start mariadb service
     ansible.builtin.service:
      name: mariadb
      state: started
      enabled: yes

   - name: Create a new database
     community.mysql.mysql_db:
      name: "{{dbname}}"
      state: present
      login_unix_socket: /var/lib/mysql/mysql.sock

   - name: Create database
     community.mysql.mysql_user:
      name: "{{dbuser}}"
      password: "{{dbpass}}"
      priv: '*.*:ALL'
      state: present
      login_unix_socket: /var/lib/mysql/mysql.sock
     register: dbout

   - name: print dbout variable
     debug:
       var: dbout

==============================================================================

ubuntu@control:~/vprofile/exercise8$ ansible-playbook db.yaml

# %% [markdown]
# ####**196. Variables de groupe et d'hôte**

# %%
ubuntu@control:~/vprofile$ ls
exercise1  exercise2  exercise3  exercise4  exercise5  exercise6  exercise7  exercise8
ubuntu@control:~/vprofile$ cd exercise8/
ubuntu@control:~/vprofile/exercise8$ ls
ansible.cfg  clientkey.pem  db.yaml  inventory
ubuntu@control:~/vprofile/exercise8$ mkdir group_vars
ubuntu@control:~/vprofile/exercise8$ vim group_vars/all
ubuntu@control:~/vprofile/exercise8$ ansible-playbook db.yaml


ubuntu@control:~/vprofile/exercise8$ vim db.yaml
============================================================================
---
- name: DBserver setup
  hosts: dbservers
  become: yes
  # :vars:
    # dbname: electric
    # dbuser: current
    # dbpass: tesla
  tasks:
   - debug:
      msg: "The dbname is {{dbname}}"

   - debug:
      var: dbname

   - name: Install mariadb-server
     ansible.builtin.yum:
      name : mariadb-server
      state: present

   - name: Install pymysql
     ansible.builtin.yum:
      name : python3-PyMySQL
      state: present

   - name: Start mariadb service
     ansible.builtin.service:
      name: mariadb
      state: started
      enabled: yes

   - name: Create a new database
     community.mysql.mysql_db:
      name: "{{dbname}}"
      state: present
      login_unix_socket: /var/lib/mysql/mysql.sock

   - name: Create database
     community.mysql.mysql_user:
      name: "{{dbuser}}"
      password: "{{dbpass}}"
      priv: '*.*:ALL'
      state: present
      login_unix_socket: /var/lib/mysql/mysql.sock
     register: dbout

   - name: print dbout variable
     debug:
       var: dbout

============================================================================

ubuntu@control:~/vprofile/exercise8$ ansible-playbook db.yaml
ubuntu@control:~/vprofile/exercise8$ cd ..
ubuntu@control:~/vprofile$ ls
ubuntu@control:~/vprofile$ cp -r exercise8 exercise9
ubuntu@control:~/vprofile$ cd exercise9/
ubuntu@control:~/vprofile/exercise9$ ls
ubuntu@control:~/vprofile/exercise9$ rm -rf db.yaml
ubuntu@control:~/vprofile/exercise9$ rm -rf group_vars
ubuntu@control:~/vprofile/exercise9$ ls
ubuntu@control:~/vprofile/exercise9$ vim vars_precedence.yaml

=============================================================================
---
- name: Undersatnding vars
  hosts: all
  become: yes
  vars:
    USRNM: playuser
    COMM: variable from playbook
  tasks:
    - name: create user
      ansible.builtin.user:
        name: "{{USRNM}}"
        comment: "{{COMM}}"
============================================================================

ubuntu@control:~/vprofile/exercise9$ ansible-playbook vars_precedence.yaml
ubuntu@control:~/vprofile/exercise9$ vim vars_precedence.yaml

==========================================================================
---
- name: Undersatnding vars
  hosts: all
  become: yes
  vars:
    USRNM: playuser
    COMM: variable from playbook
  tasks:
    - name: create user
      ansible.builtin.user:
        name: "{{USRNM}}"
        comment: "{{COMM}}"
      register: usrout

    - debug:
        var: usrout

==========================================================================

ubuntu@control:~/vprofile/exercise9$ ansible-playbook vars_precedence.yaml
ubuntu@control:~/vprofile/exercise9$ vim vars_precedence.yaml

=========================================================================
---
- name: Undersatnding vars
  hosts: all
  become: yes
  vars:
    USRNM: playuser
    COMM: variable from playbook
  tasks:
    - name: create user
      ansible.builtin.user:
        name: "{{USRNM}}"
        comment: "{{COMM}}"
      register: usrout

    - debug:
        var: usrout.name

    - debug:
        var: usrout.comment

=========================================================================

ubuntu@control:~/vprofile/exercise9$ ansible-playbook vars_precedence.yaml
ubuntu@control:~/vprofile/exercise9$ ls
ubuntu@control:~/vprofile/exercise9$ mkdir group_vars
ubuntu@control:~/vprofile/exercise9$ vim group_vars/all
=========================================================================
USRNM: commonuser
COMM: variable from groupvars_all file
=========================================================================

ubuntu@control:~/vprofile/exercise9$ cat group_vars/all
ubuntu@control:~/vprofile/exercise9$ cat vars_precedence.yaml
ubuntu@control:~/vprofile/exercise9$ ansible-playbook vars_precedence.yaml
ubuntu@control:~/vprofile/exercise9$ vim vars_precedence.yaml

============================================================================
---
- name: Undersatnding vars
  hosts: all
  become: yes
  #vars:
    #USRNM: playuser
    #COMM: variable from playbook
  tasks:
    - name: create user
      ansible.builtin.user:
        name: "{{USRNM}}"
        comment: "{{COMM}}"
      register: usrout

    - debug:
        var: usrout.name

    - debug:
        var: usrout.comment
============================================================================


ubuntu@control:~/vprofile/exercise9$ cat group_vars/all
ubuntu@control:~/vprofile/exercise9$ cat group_vars/webservers
ubuntu@control:~/vprofile/exercise9$ cat vars_precedence.yaml
ubuntu@control:~/vprofile/exercise9$ ansible-playbook vars_precedence.yaml

ubuntu@control:~/vprofile/exercise9$ ls
ubuntu@control:~/vprofile/exercise9$ mkdir host_vars
ubuntu@control:~/vprofile/exercise9$ vim host_vars/web02
===========================================================================
USRNM: web02user
COMM: variables from host_vars/web02 file
===========================================================================

ubuntu@control:~/vprofile/exercise9$ cat group_vars/all
ubuntu@control:~/vprofile/exercise9$ cat group_vars/webservers
ubuntu@control:~/vprofile/exercise9$ cat host_vars/web02
ubuntu@control:~/vprofile/exercise9$ ansible-playbook vars_precedence.yaml
ubuntu@control:~/vprofile/exercise9$ vim vars_precedence.yaml

======================================================================
---
- name: Undersatnding vars
  hosts: all
  become: yes
  vars:
    USRNM: playuser
    COMM: variable from playbook
  tasks:
    - name: create user
      ansible.builtin.user:
        name: "{{USRNM}}"
        comment: "{{COMM}}"
      register: usrout

    - debug:
        var: usrout.name

    - debug:
        var: usrout.comment
======================================================================

ubuntu@control:~/vprofile/exercise9$ ansible-playbook vars_precedence.yaml
ubuntu@control:~/vprofile/exercise9$ ansible-playbook -e USRNM=cliuser -e COMM=cliuser vars_precedence.yaml
ubuntu@control:~/vprofile/exercise9$ ls
ubuntu@control:~/vprofile/exercise9$ ls group_vars/

# %% [markdown]
# ####**197. Variables factuelles**

# %%
ubuntu@control:~/vprofile$ ls
ubuntu@control:~/vprofile$ cd exercise9/
ubuntu@control:~/vprofile/exercise9$ ls
ubuntu@control:~/vprofile/exercise9$ ansible-playbook vars_precedence.yaml
ubuntu@control:~/vprofile/exercise9$ vim vars_precedence.yaml

=====================================================
---
- name: Undersatnding vars
  hosts: all
  become: yes
  gather_facts: False
  vars:
    USRNM: playuser
    COMM: variable from playbook
  tasks:
    - name: create user
      ansible.builtin.user:
        name: "{{USRNM}}"
        comment: "{{COMM}}"
      register: usrout

    - debug:
        var: usrout.name

    - debug:
        var: usrout.comment

=====================================================

ubuntu@control:~/vprofile/exercise9$ ansible-playbook vars_precedence.yaml
ubuntu@control:~/vprofile/exercise9$ ansible -m setup web01
ubuntu@control:~/vprofile/exercise9$ vim print_facts.yaml
============================================================
---
- name:
  hosts: all
  tasks:
   - name: Print OS name
     debug:
       var: ansible_distribution
============================================================
ubuntu@control:~/vprofile/exercise9$ cat print_facts.yaml
ubuntu@control:~/vprofile/exercise9$ ansible-playbook print_facts.yaml
ubuntu@control:~/vprofile/exercise9$ vim print_facts.yaml

============================================================
---
- name:
  hosts: all
  gather_facts: False
  tasks:
   - name: Print OS name
     debug:
       var: ansible_distribution
============================================================

ubuntu@control:~/vprofile/exercise9$ vim inventory
===================================================================
all:
 hosts:
  web01:
   ansible_host: 172.31.34.120
  web02:
   ansible_host: 172.31.35.70
  web03:
   ansible_host: 172.31.36.152
  db01:
   ansible_host: 172.31.32.52

 children:
  webservers:
   hosts:
    web01:
    web02:
    web03:
  dbservers:
   hosts:
    db01:
  dc_oregon:
   children:
    webservers:
    dbservers:
   vars:
    ansible_user: ec2-user
    ansible_ssh_private_key_file: clientkey.pem
===================================================================

ubuntu@control:~/vprofile/exercise9$ ansible -m ping all
ubuntu@control:~/vprofile/exercise9$ vim inventory
==================================================================
all:
 hosts:
  web01:
   ansible_host: 172.31.34.120
  web02:
   ansible_host: 172.31.35.70
  web03:
   ansible_host: 172.31.36.152
   ansible_user: ubuntu
  db01:
   ansible_host: 172.31.32.52

 children:
  webservers:
   hosts:
    web01:
    web02:
    web03:
  dbservers:
   hosts:
    db01:
  dc_oregon:
   children:
    webservers:
    dbservers:
   vars:
    ansible_user: ec2-user
    ansible_ssh_private_key_file: clientkey.pem
==================================================================

ubuntu@control:~/vprofile/exercise9$ ansible -m ping all
ubuntu@control:~/vprofile/exercise9$ ls
ubuntu@control:~/vprofile/exercise9$ ansible-playbook print_facts.yaml
ubuntu@control:~/vprofile/exercise9$ ansible -m setup web01
ubuntu@control:~/vprofile/exercise9$ vim print_facts.yaml

=================================================================
---
- name:
  hosts: all
    #gather_facts: False
  tasks:
   - name: Print OS name
     debug:
       var: ansible_distribution
   - name: Print selinux mode
     debug:
       var: ansible_selinux_mode
   - name: Print RAM memory
     debug:
       var: ansible_memory_mb.real.free

=================================================================

ubuntu@control:~/vprofile/exercise9$ ansible-playbook print_facts.yaml
ubuntu@control:~/vprofile/exercise9$ ansible -m setup web01
ubuntu@control:~/vprofile/exercise9$ vim print_facts.yaml

=================================================================
---
- name:
  hosts: all
    #gather_facts: False
  tasks:
   - name: Print OS name
     debug:
       var: ansible_distribution
   - name: Print selinux mode
     debug:
       var: ansible_selinux_mode
   - name: Print RAM memory
     debug:
       var: ansible_memory_mb.real.free

   - name: Print Propcessor name
     debug:
       var: ansible_processor[2]

=================================================================

ubuntu@control:~/vprofile/exercise9$ ansible-playbook print_facts.yaml

# %% [markdown]
# ###**198. Prise de décision**
#
# ####**Serveur de provisionnement**
# + 1. Service NTP sur multi OS
# + 2. Utilisateurs et groupes
# + 3. Fichiers de configuration
# + 4. Prise de décision
# + 5. Boucles
# + 6. Modèles
# + 7. Manutentionnaires
# + 8. Rôles Ansibles

# %%
ubuntu@control:~$ ls
ubuntu@control:~$ cd vprofile/
ubuntu@control:~/vprofile$ ls
ubuntu@control:~/vprofile$ cp -r exercise9 exercise10
ubuntu@control:~/vprofile$ cd exercise10/
ubuntu@control:~/vprofile/exercise10$ ls
ubuntu@control:~/vprofile/exercise10$ rm -rf print_facts.yaml vars_precedence.yaml
ubuntu@control:~/vprofile/exercise10$ ls
ansible.cfg  clientkey.pem  group_vars  host_vars  inventory
ubuntu@control:~/vprofile/exercise10$ ansible -m ping all
ubuntu@control:~/vprofile/exercise10$ vim provisioning.yaml
============================================================================
---
- name: Provisioning servers
  hosts: all
  become: yes
  tasks:
    - name: Install ntp agent
      yum:
        name: chrony
        state: present
      when: ansible_distribution == 'CentOS'

    - name: Install ntp agent
      apt:
        name: ntp
        state: present
        update_cache: yes
      when: ansible_distribution == 'Ubuntu'

    - name: Start service on centos
      service:
        name: chrony
        state: started
        enabled: yes
      when: ansible_distribution == 'Centos'

    - name: Start service on ubuntu
      service:
        name: ntp
        state: started
        enabled: yes
      when: ansible_distribution == 'Ubuntu'

============================================================================
ubuntu@control:~/vprofile/exercise10$ ansible-playbook provisioning.yaml

# %% [markdown]
# + chatgpt ⁉
#   + ***ansible playbook to install chrony on centos and ntp on ubuntu. Also start and enablechrony and ntp service.***

# %%
---
- name: Provisioning NTP/Chrony Agents
  hosts: all
  become: yes

  tasks:
    - name: Install ntp agent on CentOS
      yum:
        name: chrony
        state: present
      when: ansible_distribution == 'CentOS'

    - name: Install ntp agent on Ubuntu
      apt:
        name: ntp
        state: present
      when: ansible_distribution == 'Ubuntu'

    - name: Start and enable chrony service on CentOS
      systemd:
        name: chronyd
        state: started
        enabled: yes
      when: ansible_distribution == 'CentOS'

    - name: Start and enable ntp service on Ubuntu
      systemd:
        name: ntp
        state: started
        enabled: yes
      when: ansible_distribution == 'Ubuntu'

# %%
ansible-playbook -i inventory.ini install_ntp_chrony.yml

# %% [markdown]
# ####**Loops**

# %%
ubuntu@control:~/vprofile$ ls
ubuntu@control:~/vprofile$ cp -r exercise10 exercise11
ubuntu@control:~/vprofile$ cd exercise11/
ubuntu@control:~/vprofile/exercise11$ ls
ubuntu@control:~/vprofile/exercise11$ vim provisioning.yaml
=======================================================================
---
- name: Provisioning servers
  hosts: all
  become: yes
  tasks:
    - name: Install ntp agent
      yum:
        name: "{{item}}"
        state: present
      when: ansible_distribution == 'CentOS'
      loop:
        - chrony
        - wget
        - git
        - zip
        - unzip

    - name: Install ntp agent
      apt:
        name: "{{item}}"
        state: present
        update_cache: yes
      when: ansible_distribution == 'Ubuntu'
      loop:
        - ntp
        - wget
        - git
        - zip
        - unzip

    - name: Start service on centos
      service:
        name: chrony
        state: started
        enabled: yes
      when: ansible_distribution == 'Centos'

    - name: Start service on ubuntu
      service:
        name: ntp
        state: started
        enabled: yes
      when: ansible_distribution == 'Ubuntu'

=======================================================================
ubuntu@control:~/vprofile/exercise11$ ansible-playbook provisioning.yaml

# %% [markdown]
# ####**200. Modules de fichiers, de copies et de modèles**

# %%
ubuntu@control:~$ ls
ubuntu@control:~$ cd vprofile/
ubuntu@control:~/vprofile$ ls
ubuntu@control:~/vprofile$ cp -r exercise11 exercise12
ubuntu@control:~/vprofile$ cd exercise12/
ubuntu@control:~/vprofile/exercise12$ top
ubuntu@control:~/vprofile/exercise12$ vim provisioning.yaml
============================================================================
- name: Provisioning servers
  hosts: all
  become: yes
  tasks:
    - name: Install ntp agent
      yum:
        name: "{{item}}"
        state: present
      when: ansible_distribution == 'CentOS'
      loop:
        - chrony
        - wget
        - git
        - zip
        - unzip

    - name: Install ntp agent
      apt:
        name: "{{item}}"
        state: present
        update_cache: yes
      when: ansible_distribution == 'Ubuntu'
      loop:
        - ntp
        - wget
        - git
        - zip
        - unzip

    - name: Start service on centos
      service:
        name: chrony
        state: started
        enabled: yes
      when: ansible_distribution == 'Centos'

    - name: Start service on ubuntu
      service:
        name: ntp
        state: started
        enabled: yes
      when: ansible_distribution == 'Ubuntu'

    - name: Banner file
      copy:
        content: '# This server is managed by ansible. No manual changes please.'
        dest: /etc/motd

============================================================================

ubuntu@control:~/vprofile/exercise12$ ansible-playbook provisioning.yaml
ubuntu@control:~/vprofile/exercise12$ cat inventory
ubuntu@control:~/vprofile/exercise12$ ssh -i clientkey.pem ec2-user@172.31.32.52
[ec2-user@ip-172-31-32-52 ~]$ sudo -i
[root@ip-172-31-32-52 ~]# cat /etc/chrony.conf
[root@ip-172-31-32-52 ~]# exit
[ec2-user@ip-172-31-32-52 ~]$ exit
ubuntu@control:~/vprofile/exercise12$ ls
ubuntu@control:~/vprofile/exercise12$ mkdir templates
ubuntu@control:~/vprofile/exercise12$ vim templates/ntpconf_centos
root@ip-172-31-36-152:~# exit
ubuntu@ip-172-31-36-152:~$ exit
Connection to 172.31.36.152 closed.
ubuntu@control:~/vprofile/exercise12$ vim templates/ntpconf_ubuntu
=============================================================================
# Use public servers from the pool.ntp.org project.
# Please consider joining the pool (https://www.pool.ntp.org/join.html).
pool 2.centos.pool.ntp.org iburst

# Use NTP servers from DHCP.
sourcedir /run/chrony-dhcp

# Record the rate at which the system clock gains/losses time.
driftfile /var/lib/chrony/drift

# Allow the system clock to be stepped in the first three updates
# if its offset is larger than 1 second.
makestep 1.0 3

# Enable kernel synchronization of the real-time clock (RTC).
rtcsync

# Enable hardware timestamping on all interfaces that support it.
#hwtimestamp *

# Increase the minimum number of selectable sources required to adjust
# the system clock.
#minsources 2

# Allow NTP client access from local network.
#allow 192.168.0.0/16

# Serve time even if not synchronized to a time source.
#local stratum 10

# Require authentication (nts or key option) for all NTP sources.
#authselectmode require

# Specify file containing keys for NTP authentication.
keyfile /etc/chrony.keys

# Save NTS keys and cookies.
ntsdumpdir /var/lib/chrony

# Insert/delete leap seconds by slewing instead of stepping.
#leapsecmode slew

# Get TAI-UTC offset and leap seconds from the system tz database.
leapsectz right/UTC

# Specify directory for log files.
logdir /var/log/chrony

# Select which information is logged.
#log measurements statistics tracking

# Amazon Time Sync Service
server 169.254.169.123 prefer iburst minpoll 4 maxpoll 4
=============================================================================
ubuntu@control:~/vprofile/exercise12$ cat inventory
ubuntu@control:~/vprofile/exercise12$ ssh -i clientkey.pem ubuntu@172.31.36.152
ubuntu@ip-172-31-36-152:~$ sudo -i
root@ip-172-31-36-152:~# cat /etc/ntp.conf

===============================================================================
# /etc/ntp.conf, configuration for ntpd; see ntp.conf(5) for help

driftfile /var/lib/ntp/ntp.drift

# Leap seconds definition provided by tzdata
leapfile /usr/share/zoneinfo/leap-seconds.list

# Enable this if you want statistics to be logged.
#statsdir /var/log/ntpstats/

statistics loopstats peerstats clockstats
filegen loopstats file loopstats type day enable
filegen peerstats file peerstats type day enable
filegen clockstats file clockstats type day enable

# Specify one or more NTP servers.

# Use servers from the NTP Pool Project. Approved by Ubuntu Technical Board
# on 2011-02-08 (LP: #104525). See http://www.pool.ntp.org/join.html for
# more information.
pool 0.ubuntu.pool.ntp.org iburst
pool 1.ubuntu.pool.ntp.org iburst
pool 2.ubuntu.pool.ntp.org iburst
pool 3.ubuntu.pool.ntp.org iburst

# Use Ubuntu's ntp server as a fallback.
pool ntp.ubuntu.com

# Access control configuration; see /usr/share/doc/ntp-doc/html/accopt.html for
# details.  The web page <http://support.ntp.org/bin/view/Support/AccessRestrictions>
# might also be helpful.
#
# Note that "restrict" applies to both servers and clients, so a configuration
# that might be intended to block requests from certain clients could also end
# up blocking replies from your own upstream servers.

# By default, exchange time with everybody, but don't allow configuration.
restrict -4 default kod notrap nomodify nopeer noquery limited
restrict -6 default kod notrap nomodify nopeer noquery limited

# Local users may interrogate the ntp server more closely.
restrict 127.0.0.1
restrict ::1

# Needed for adding pool entries
restrict source notrap nomodify noquery

# Clients from this (example!) subnet have unlimited access, but only if
# cryptographically authenticated.
#restrict 192.168.123.0 mask 255.255.255.0 notrust


# If you want to provide time to your local subnet, change the next line.
# (Again, the address is an example only.)
#broadcast 192.168.123.255

# If you want to listen to time broadcasts on your local subnet, de-comment the
# next lines.  Please do this only if you trust everybody on the network!
#disable auth
#broadcastclient
===============================================================================

ubuntu@control:~/vprofile/exercise12$ vim provisioning.yaml
==============================================================================
    - name: Start service on centos
      service:
        name: chrony
        state: started
        enabled: yes
      when: ansible_distribution == 'Centos'

    - name: Start service on ubuntu
      service:
        name: ntp
        state: started
        enabled: yes
      when: ansible_distribution == 'Ubuntu'

    - name: Banner file
      copy:
        content: '# This server is managed by ansible. No manual changes please.'
        dest: /etc/motd

    - name: Deploy ntp agent conf on centos
      template:
        src: templates/ntpconf_centos
        dest: /etc/chrony.conf
        backup: yes
      when: ansible_distribution == 'Centos'

    - name: Deploy ntp agent conf on ubuntu
      template:
        src: templates/ntpconf_ubuntu
        dest: /etc/ntp.conf
        backup: yes
      when: ansible_distribution == 'Ubuntu'

    - name: reStart service on centos
      service:
        name: chrony
        state: restarted
        enabled: yes
      when: ansible_distribution == 'Centos'

    - name: reStart service on ubuntu
      service:
        name: ntp
        state: restarted
        enabled: yes
      when: ansible_distribution == 'Ubuntu'

==============================================================================
ubuntu@control:~/vprofile/exercise12$ ansible-playbook provisioning.yaml
ubuntu@control:~/vprofile/exercise12$ vim templates/ntpconf_ubuntu
ubuntu@control:~/vprofile/exercise12$ ls
ubuntu@control:~/vprofile/exercise12$ vim group_vars/all
=============================================================================
USRNM: commonuser
COMM: variable from groupvars_all file
ntp0: 0.north-america.pool.ntp.org
ntp1: 1.north-america.pool.ntp.org
ntp2: 2.north-america.pool.ntp.org
ntp3: 3.north-america.pool.ntp.org
=============================================================================

ubuntu@control:~/vprofile/exercise12$ vim templates/ntpconf_centos

=============================================================================
# Use public servers from the pool.ntp.org project.
# Please consider joining the pool (https://www.pool.ntp.org/join.html).
pool "{{ntp0}}" iburst
pool "{{ntp1}}" iburst
pool "{{ntp2}}" iburst
pool "{{ntp3}}" iburst

# Use NTP servers from DHCP.
sourcedir /run/chrony-dhcp

# Record the rate at which the system clock gains/losses time.
driftfile /var/lib/chrony/drift

# Allow the system clock to be stepped in the first three updates
# if its offset is larger than 1 second.
makestep 1.0 3

# Enable kernel synchronization of the real-time clock (RTC).
rtcsync

# Enable hardware timestamping on all interfaces that support it.
#hwtimestamp *

# Increase the minimum number of selectable sources required to adjust
# the system clock.
#minsources 2

# Allow NTP client access from local network.
#allow 192.168.0.0/16

# Serve time even if not synchronized to a time source.
#local stratum 10

# Require authentication (nts or key option) for all NTP sources.
#authselectmode require

# Specify file containing keys for NTP authentication.
keyfile /etc/chrony.keys

# Save NTS keys and cookies.
ntsdumpdir /var/lib/chrony

# Insert/delete leap seconds by slewing instead of stepping.
#leapsecmode slew

# Get TAI-UTC offset and leap seconds from the system tz database.
leapsectz right/UTC
=============================================================================


ubuntu@control:~/vprofile/exercise12$ vim templates/ntpconf_ubuntu
=============================================================================
filegen clockstats file clockstats type day enable

# Specify one or more NTP servers.

# Use servers from the NTP Pool Project. Approved by Ubuntu Technical Board
# on 2011-02-08 (LP: #104525). See http://www.pool.ntp.org/join.html for
# more information.
pool "{{ntp0}}" iburst
pool "{{ntp1}}" iburst
pool "{{ntp2}}" iburst
pool "{{ntp3}}" iburst

# Use Ubuntu's ntp server as a fallback.
pool ntp.ubuntu.com

# Access control configuration; see /usr/share/doc/ntp-doc/html/accopt.html for
# details.  The web page <http://support.ntp.org/bin/view/Support/AccessRestrictions>
# might also be helpful.
#
# Note that "restrict" applies to both servers and clients, so a configuration
# that might be intended to block requests from certain clients could also end
# up blocking replies from your own upstream servers.

# By default, exchange time with everybody, but don't allow configuration.
restrict -4 default kod notrap nomodify nopeer noquery limited
restrict -6 default kod notrap nomodify nopeer noquery limited

# Local users may interrogate the ntp server more closely.
restrict 127.0.0.1
restrict ::1

# Needed for adding pool entries
restrict source notrap nomodify noquery

# Clients from this (example!) subnet have unlimited access, but only if
# cryptographically authenticated.
#restrict 192.168.123.0 mask 255.255.255.0 notrust


# If you want to provide time to your local subnet, change the next line.
# (Again, the address is an example only.)
#broadcast 192.168.123.255

# If you want to listen to time broadcasts on your local subnet, de-comment the
# next lines.  Please do this only if you trust everybody on the network!
#disable auth
#broadcastclient
=============================================================================

ubuntu@control:~/vprofile/exercise12$ ansible-playbook provisioning.yaml
ubuntu@control:~/vprofile/exercise12$ vim provisioning.yaml
==============================================================================

    - name: Start service on ubuntu
      service:
        name: ntp
        state: started
        enabled: yes
      when: ansible_distribution == 'Ubuntu'

    - name: Banner file
      copy:
        content: '# This server is managed by ansible. No manual changes please.'
        dest: /etc/motd

    - name: Deploy ntp agent conf on centos
      template:
        src: templates/ntpconf_centos
        dest: /etc/chrony.conf
        backup: yes
      when: ansible_distribution == 'Centos'

    - name: Deploy ntp agent conf on ubuntu
      template:
        src: templates/ntpconf_ubuntu
        dest: /etc/ntp.conf
        backup: yes
      when: ansible_distribution == 'Ubuntu'

    - name: reStart service on centos
      service:
        name: chrony
        state: restarted
        enabled: yes
      when: ansible_distribution == 'Centos'

    - name: reStart service on ubuntu
      service:
        name: ntp
        state: restarted
        enabled: yes
      when: ansible_distribution == 'Ubuntu'

    - name: Create a folder
      file:
        path: /opt/test21
        state: directory
==============================================================================

ubuntu@control:~/vprofile/exercise12$ ansible-playbook provisioning.yaml

# %% [markdown]
# ####**201. Handlers**

# %%
ubuntu@control:~/vprofile$ ls
ubuntu@control:~/vprofile$ cp -r exercise12 exercise13
ubuntu@control:~/vprofile$ cd exercise13/
ubuntu@control:~/vprofile/exercise13$ ls
ubuntu@control:~/vprofile/exercise13$ vim provisioning.yaml
=============================================================================
        name: ntp
        state: started
        enabled: yes
      when: ansible_distribution == 'Ubuntu'

    - name: Banner file
      copy:
        content: '# This server is managed by ansible. No manual changes please.'
        dest: /etc/motd

    - name: Create a folder
      file:
        path: /opt/test21
        state: directory

    - name: Deploy ntp agent conf on centos
      template:
        src: templates/ntpconf_centos
        dest: /etc/chrony.conf
        backup: yes
      when: ansible_distribution == 'Centos'
      notify:
        - reStart service on centos

    - name: Deploy ntp agent conf on ubuntu
      template:
        src: templates/ntpconf_ubuntu
        dest: /etc/ntp.conf
        backup: yes
      when: ansible_distribution == 'Ubuntu'
      notify:
        - reStart service on ubuntu

  handlers:
    - name: reStart service on centos
      service:
        name: chrony
        state: restarted
        enabled: yes
      when: ansible_distribution == 'Centos'

    - name: reStart service on ubuntu
      service:
        name: ntp
        state: restarted
        enabled: yes
      when: ansible_distribution == 'Ubuntu'
=============================================================================

ubuntu@control:~/vprofile/exercise13$ ansible-playbook provisioning.yaml
ubuntu@control:~/vprofile/exercise13$ vim templates/ntpconf_centos
=============================================================================
# Use public servers from the pool.ntp.org project.
# Please consider joining the pool (https://www.pool.ntp.org/join.html).
pool "{{ntp0}}" iburst
pool "{{ntp1}}" iburst
pool "{{ntp2}}" iburst
pool "{{ntp3}}" iburst
####
# Use NTP servers from DHCP.
sourcedir /run/chrony-dhcp

# Record the rate at which the system clock gains/losses time.
driftfile /var/lib/chrony/drift

# Allow the system clock to be stepped in the first three updates
# if its offset is larger than 1 second.
makestep 1.0 3

# Enable kernel synchronization of the real-time clock (RTC).
rtcsync

# Enable hardware timestamping on all interfaces that support it.
#hwtimestamp *

# Increase the minimum number of selectable sources required to adjust
# the system clock.
#minsources 2

# Allow NTP client access from local network.
#allow 192.168.0.0/16

# Serve time even if not synchronized to a time source.
#local stratum 10

# Require authentication (nts or key option) for all NTP sources.
#authselectmode require

# Specify file containing keys for NTP authentication.
keyfile /etc/chrony.keys

# Save NTS keys and cookies.
ntsdumpdir /var/lib/chrony

# Insert/delete leap seconds by slewing instead of stepping.
#leapsecmode slew

# Get TAI-UTC offset and leap seconds from the system tz database.
leapsectz right/UTC

=============================================================================

# %% [markdown]
# ####**Roles**
#
# + ***Bonjour et bienvenue dans la session sur les rôles Ansible. Avant d'obtenir et de créer des rôles Ansible, comprenons pourquoi le faisons-nous et comment cela fonctionne-t-il vraiment ?***
#
# + ***Les rôles Ansible consistent à simplifier le contenu de votre playbook. Maintenant, nous avons un playbook qui contient tellement de choses. Nous avons la Déclaration mondiale où nous pouvons mentionner des options comme devenir ou même des variables. Nous avons beaucoup de variables.***
#
# + ***Nous pouvons les avoir à l'intérieur du playbook ou à l'extérieur comme dans le fichier `VARs de groupe ou d'hôte`. Nous avons beaucoup de tâches, de fichiers que nous poussons, de modèles, de gestionnaires et vous pourriez en avoir beaucoup plus des choses. Nous avons vu maintenant déjà playbook où nous provisionnons un service qui est aussi un service très simple, mais il y a déjà trop de données dans notre playbook qui devient difficile à gérer maintenant.***
#
# + **Votre structure de répertoires ressemble à ceci.**
#
#   + ***Nous avons un fichier de configuration.***
#
#   + ***Nous avons un répertoire de fichiers.***
#
#   + ***Vous pouvez pousser certains fichiers.***
#
#   + ***Nous avons des playbooks de modèles d'inventaire.***
#
#   + ***Et tant de choses dans nos playbooks.***
#
#
#
# + ***Comme nous pouvons avoir des variables. Nous avons beaucoup de modèles de gestionnaires de tâches, copiez le module pour rendre ce code plus gérable. Nous pouvons utiliser des rôles Ansible qui simplifient vraiment ou séparent tout le contenu de notre playbook.***
#
# + ***Mais nous devons d'abord identifier ce rôle des serveurs qui sont dans notre infrastructure. Vous pouvez donc avoir des ordinateurs qui jouent différents types de rôles, certains MySQL, certains Tomcat,
# certains serveurs de construction, certains Apache et des configurations courantes.***
#
# + ***Par exemple, ce que nous avons fait pourrait être commun à tous vos serveurs ou à un agent de surveillance ou à un agent de journalisation. Ainsi, certains serveurs peuvent jouer un rôle très courant sur chaque serveur. Vous aurez un agent de surveillance, une configuration selon la norme de votre organisation, d'autres jouant un rôle très spécifique comme la base de données MySQL ou la base de données Oracle ou le serveur d'applications comme Tomcat.***
#
# + ***Ainsi, si vous identifiez les rôles, vous pouvez créer une structure de répertoire de rôles. Donc, vous créez un répertoire appelé en tant que rôles à l'intérieur duquel vous créez un répertoire avec le nom du rôle qui aura des sous-répertoires où vous pourrez distribuer le contenu de votre playbook comme des tâches.***
#
# + ***Vous avez le fichier `main.py` qui n'aura que les modèles de tâches n'aura que le modèle. Les `VAR` n'auront que les variables var dans les principaux fichiers de fichiers point `yml` n'auront que les fichiers que vous poussez à travers. Les gestionnaires de module de copie n'auront que les gestionnaires dans le fichier `yaml` principal.***
#
# + ***Maintenant, nous distribuons ici le contenu de notre playbook dans différents répertoires d'avantages. Eh bien, il est facile d'y accéder et d'apporter des modifications. Il donne une structure modulaire à votre playbook ansible ou à votre code Ansible. Et cela, nous l'utilisons très spécifiquement pour la réutilisation.***
#
# + ***Si vous souhaitez réutiliser ce code comme pour, disons pour la majeure partie de votre projet dans votre organisation, vous avez le serveur Tomcat. Nous allons donc créer un rôle pour la configuration de Tomcat qui pourra être utilisé dans différents projets.***
#
# + ***Donc, le rôle est vraiment au niveau de l'organisation que nous créons afin que nous puissions le réutiliser dans différents projets différents ou même différents environnements différents.***
#
# + ***Si vous ne faites pas de réutilisation, il est inutile de créer des rôles. Voyons donc comment nous pouvons créer des rôles pour notre playbook que nous avons créé jusqu'à présent.***

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
ubuntu@control:~/vprofile$ ls
ubuntu@control:~/vprofile$ cp -r exercise13 exercise14
ubuntu@control:~/vprofile$ cd exercise14/
ubuntu@control:~/vprofile/exercise14$ ls

ubuntu@control:~/vprofile/exercise14$ vim provisioning.yaml
===================================================================
---
- name: Provisioning servers
  hosts: all
  become: yes
  vars:
    mydir: /opt/dir22
  tasks:
    - name: Install ntp agent
      yum:
        name: "{{item}}"
        state: present
      when: ansible_distribution == 'CentOS'
      loop:
        - chrony
        - wget
        - git
        - zip
        - unzip

    - name: Install ntp agent
      apt:
        name: "{{item}}"
        state: present
        update_cache: yes
      when: ansible_distribution == 'Ubuntu'
      loop:
        - ntp
        - wget
        - git
        - zip
        - unzip

    - name: Start service on centos
      service:
        name: chrony
        state: started
        enabled: yes
      when: ansible_distribution == 'Centos'

    - name: Start service on ubuntu
      service:
        name: ntp
        state: started
        enabled: yes
      when: ansible_distribution == 'Ubuntu'

     - name: Banner file
      copy:
        content: '# This server is managed by ansible. No manual changes please.'
        dest: /etc/motd

    - name: Create a folder
      file:
        path: "{{mydir}}"
        state: directory

    - name: Deploy ntp agent conf on centos
      template:
        src: templates/ntpconf_centos
        dest: /etc/chrony.conf
        backup: yes
      when: ansible_distribution == 'Centos'
      notify:
        - reStart service on centos

    - name: Deploy ntp agent conf on ubuntu
      template:
        src: templates/ntpconf_ubuntu
        dest: /etc/ntp.conf
        backup: yes
      when: ansible_distribution == 'Ubuntu'
      notify:
        - reStart service on ubuntu

    - name: Dump file
      copy:
        src: files/myfile.txt
        dest: /tmp/myfile.txt

  handlers:
    - name: reStart service on centos
      service:
        name: chrony
        state: restarted
        enabled: yes
      when: ansible_distribution == 'Centos'

    - name: reStart service on ubuntu
      service:
        name: ntp
        state: restarted
        enabled: yes
      when: ansible_distribution == 'Ubuntu'
===================================================================

ubuntu@control:~/vprofile/exercise14$ ls
ubuntu@control:~/vprofile/exercise14$ mkdir files
ubuntu@control:~/vprofile/exercise14$ vim files/myfile.txt
ubuntu@control:~/vprofile/exercise14$ ansible-playbook provisioning.yaml
ubuntu@control:~/vprofile/exercise14$ ls
ubuntu@control:~/vprofile/exercise14$ sudo apt install tree -y
ubuntu@control:~/vprofile/exercise14$ cd ..
ubuntu@control:~/vprofile$ tree exercise14
ubuntu@control:~/vprofile$ cd exercise14/
ubuntu@control:~/vprofile/exercise14$ mkdir roles
ubuntu@control:~/vprofile/exercise14$ cd roles/
ubuntu@control:~/vprofile/exercise14/roles$ ansible-galaxy init post-install
ubuntu@control:~/vprofile/exercise14/roles$ ls
ubuntu@control:~/vprofile/exercise14/roles$ tree
ubuntu@control:~/vprofile/exercise14/roles$ cd ..
ubuntu@control:~/vprofile/exercise14$ cat group_vars/all
ubuntu@control:~/vprofile/exercise14$ vim roles/post-install/vars/main.yml
==============================================================================
---
# vars file for post-install
USRNM: commonuser
COMM: variable from groupvars_all file
ntp0: 0.north-america.pool.ntp.org
ntp1: 1.north-america.pool.ntp.org
ntp2: 2.north-america.pool.ntp.org
ntp3: 3.north-america.pool.ntp.org
mydir: /opt/dir22
==============================================================================

ubuntu@control:~/vprofile/exercise14$ cat provisioning.yaml
ubuntu@control:~/vprofile/exercise14$ rm -rf group_vars host_vars
ubuntu@control:~/vprofile/exercise14$ ls
ubuntu@control:~/vprofile/exercise14$ cp files/* roles/post-install/files/
ubuntu@control:~/vprofile/exercise14$ cp templates/* roles/post-install/templates/
ubuntu@control:~/vprofile/exercise14$ ls
ubuntu@control:~/vprofile/exercise14$ cat provisioning.yaml

ubuntu@control:~/vprofile/exercise14$ vim roles/post-install/handlers/main.yml
=============================================================================
---
# handlers file for post-install
- name: reStart service on centos
  service:
    name: chrony
    state: restarted
    enabled: yes
  when: ansible_distribution == 'Centos'

- name: reStart service on ubuntu
  service:
    name: ntp
    state: restarted
    enabled: yes
  when: ansible_distribution == 'Ubuntu'
=============================================================================

ubuntu@control:~/vprofile/exercise14$ vim roles/post-install/tasks/main.yml
============================================================================
---
# tasks file for post-install
tasks:
- name: Install ntp agent
  yum:
    name: "{{item}}"
    state: present
    when: ansible_distribution == 'CentOS'
    loop:
      - chrony
      - wget
      - git
      - zip
      - unzip

- name: Install ntp agent
  apt:
    name: "{{item}}"
    state: present
    update_cache: yes
    when: ansible_distribution == 'Ubuntu'
    loop:
      - ntp
      - wget
      - git
      - zip
      - unzip

- name: Start service on centos
  service:
    name: chrony
    state: started
    enabled: yes
  when: ansible_distribution == 'Centos'
- name: Start service on ubuntu
  service:
    name: ntp
    state: started
    enabled: yes
  when: ansible_distribution == 'Ubuntu'

- name: Banner file
  copy:
    content: '# This server is managed by ansible. No manual changes please.'
    dest: /etc/motd

- name: Create a folder
  file:
    path: "{{mydir}}"
    state: directory

- name: Deploy ntp agent conf on centos
  template:
    src: ntpconf_centos.j2
    dest: /etc/chrony.conf
    backup: yes
  when: ansible_distribution == 'Centos'
  notify:
    - reStart service on centos

- name: Deploy ntp agent conf on ubuntu
  template:
    src: ntpconf_ubuntu.j2
    dest: /etc/ntp.conf
    backup: yes
  when: ansible_distribution == 'Ubuntu'
  notify:
    - reStart service on ubuntu

- name: Dump file
  copy:
    src: myfile.txt
    dest: /tmp/myfile.txt
============================================================================

ubuntu@control:~/vprofile/exercise14$ vim provisioning.yaml
============================================================================
---
- name: Provisioning servers
  hosts: all
  become: yes
  roles:
    - post-install
============================================================================
ubuntu@control:~/vprofile/exercise14$ cat provisioning.yaml
ubuntu@control:~/vprofile/exercise14$ ls
ansible.cfg  clientkey.pem  files  inventory  provisioning.yaml  roles  templates
ubuntu@control:~/vprofile/exercise14$ rm -rf files templates
ubuntu@control:~/vprofile/exercise14$ vim provisioning.yaml
ubuntu@control:~/vprofile/exercise14$ vim roles/post-install/tasks/main.yml
ubuntu@control:~/vprofile/exercise14$ cd roles/post-install/templates/
ubuntu@control:~/vprofile/exercise14/roles/post-install/templates$ ls
ubuntu@control:~/vprofile/exercise14/roles/post-install/templates$ mv ntpconf_centos ntpconf_centos.j2
ubuntu@control:~/vprofile/exercise14/roles/post-install/templates$ ls
ubuntu@control:~/vprofile/exercise14/roles/post-install/templates$ mv ntpconf_ubuntu ntpconf_ubuntu.j2
ubuntu@control:~/vprofile/exercise14/roles/post-install/templates$ ls
ubuntu@control:~/vprofile/exercise14/roles/post-install/templates$ cd ../../..
ubuntu@control:~/vprofile/exercise14$ ls
ubuntu@control:~/vprofile/exercise14$ ansible-playbook provisioning.yaml
ubuntu@control:~/vprofile/exercise14$ tree roles/

ubuntu@control:~/vprofile/exercise14$ cd ..
ubuntu@control:~/vprofile$ cp -r exercise14 exercise15
ubuntu@control:~/vprofile$ cd exercise15/
ubuntu@control:~/vprofile/exercise15$ ls
ubuntu@control:~/vprofile/exercise15$ cat roles/post-install/vars/main.yml
ubuntu@control:~/vprofile/exercise15$ vim roles/post-install/defaults/main.yml

==============================================================================
---
# defaults file for post-install
USRNM: commonuser
COMM: variable from groupvars_all file
ntp0: 0.north-america.pool.ntp.org
ntp1: 1.north-america.pool.ntp.org
ntp2: 2.north-america.pool.ntp.org
ntp3: 3.north-america.pool.ntp.org
mydir: /opt/dir22
==============================================================================

ubuntu@control:~/vprofile/exercise15$ vim provisioning.yaml
=============================================================================
---
- name: Provisioning servers
  hosts: all
  become: yes
  roles:
    - role: post-install
      vars:
        ntp0: 0.in.pool.ntp.org
        ntp1: 1.in.pool.ntp.org
        ntp2: 2.in.pool.ntp.org
        ntp3: 3.in.pool.ntp.org

=============================================================================
ubuntu@control:~/vprofile/exercise15$ ansible-playbook provisioning.yaml

ubuntu@control:~/vprofile/exercise15$ ansible-galaxy install geerlingguy.java
ubuntu@control:~/vprofile/exercise15$ vim provisioning.yaml
============================================================================
---
- name: Provisioning servers
  hosts: all
  become: yes
  roles:
    - geerlingguy.java
    - role: post-install
      vars:
        ntp0: 0.in.pool.ntp.org
        ntp1: 1.in.pool.ntp.org
        ntp2: 2.in.pool.ntp.org
        ntp3: 3.in.pool.ntp.org
============================================================================

ubuntu@control:~/vprofile/exercise15$ ansible-playbook provisioning.yaml
ubuntu@control:~/vprofile/exercise15$ cd
ubuntu@control:~$ ls -a
ubuntu@control:~$ cd .ansible/
ubuntu@control:~/.ansible$ ls
ubuntu@control:~/.ansible$ cd roles/
ubuntu@control:~/.ansible/roles$ ls
ubuntu@control:~/.ansible/roles$ cd geerlingguy.java/
ubuntu@control:~/.ansible/roles/geerlingguy.java$ ls
ubuntu@control:~/.ansible/roles/geerlingguy.java$ tree
ubuntu@control:~/.ansible/roles/geerlingguy.java$ ls
ubuntu@control:~/.ansible/roles/geerlingguy.java$ vim tasks/main.yml
ubuntu@control:~/.ansible/roles/geerlingguy.java$ cd

# %% [markdown]
# ####**Ansible for AWS**

# %%
ubuntu@control:~$ export AWS_ACCESS_KEY_ID='AKIAYJD42CEZCH3MANOI'
ubuntu@control:~$ export AWS_SECRET_ACCESS_KEY='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'
ubuntu@control:~$ vim .bashrc
ubuntu@control:~$ source .bashrc
ubuntu@control:~$ mkdir aws
ubuntu@control:~$ cd aws/
ubuntu@control:~/aws$ sudo apt install python3-pip -y
ubuntu@control:~/aws$ pip install boto3
ubuntu@control:~/aws$ vim test-aws.yml
=======================================================
---
- name: Create EC2 Key Pair
  hosts: localhost
  gather_facts: False

  tasks:
    - name: Create key pair
      ec2_key:
        name: sample
        region: us-east-1
      register: keyout

    - name: print key
      debug:
        var: keyout

    - name: save key
      copy:
        content: "{{keyout.key.private_key}}"
        dest: ./sample.pem
      when: keyout.changed

    - name: start an instance
      amazon.aws.ec2_instance:
        name: "public-compute-instance"
        key_name: "smaple"
        #vpc_subnet_id: subnet-5ca1ab1e
        instance_type: t2.micro
        security_group: default
        #network:
          #assign_public_ip: true
        image_id: ami-08a52ddb321b32a8c
        exact_count: 1
        region: us-east-1
        tags:
          Environment: Testing
=======================================================
ubuntu@control:~/aws$ ansible-playbook test-aws.yml
ubuntu@control:~/aws$ ansible-galaxy collection install amazon.aws
